# %% [markdown]
# # **SECTION 1: Data Collection**

# %% [markdown]
# ## Objectives
#
# * Fetch and save data from Kaggle
#
# ## Inputs
#
# * Data will be saved as input

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/cherryleaves/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/cherryleaves'

# %% [markdown]
# # Fetch data from Kaggle

# %% [markdown]
# Install Kaggle to collect data

# %%
# %pip install kaggle==1.5.12
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73026 sha256=ead5466c9d86262dedebb7062f75d11a4d90ab4363588d80d0f681390971d2b4
#   Stored in directory: /home/gitpod/.cache/pip/wheels/f5/69/4d/d701fc604b9fb09be59718b4056fd5556a22588ce1f25dd090
# Successfully built kaggle
# ...
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.6.17
#     Uninstalling kaggle-1.6.17:
#       Successfully uninstalled kaggle-1.6.17
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The api had already been downloaded and installed, code below will authenticate

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
! chmod 600 kaggle.json

# %% [markdown]
# # Save Kaggle data

# %% [markdown]
# Define the Kaggle dataset, and destination folder and download it.

# %%
KaggleDatasetPath = "codeinstitute/cherry-leaves/data"
DestinationFolder = "inputs/datasets/raw"   
! kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}
# Out:
# ...
#  96%|████████████████████████████████████▌ | 53.0M/55.0M [00:02<00:00, 27.7MB/s]
# 100%|██████████████████████████████████████| 55.0M/55.0M [00:02<00:00, 24.6MB/s]

# %% [markdown]
# Unzip the downloaded file, delete the zip file and delete the kaggle.json file

# %%
! unzip {DestinationFolder}/*.zip -d {DestinationFolder} \
  && rm {DestinationFolder}/*.zip \
  && rm kaggle.json
# Out:
# Archive:  inputs/datasets/raw/cherry-leaves.zip
#   inflating: inputs/datasets/raw/cherry-leaves/healthy/0008f3d3-2f85-4973-be9a-1b520b8b59fc___JR_HL 4092.JPG
#   inflating: inputs/datasets/raw/cherry-leaves/healthy/0008f3d3-2f85-4973-be9a-1b520b8b59fc___JR_HL 4092_180deg.JPG
#   inflating: inputs/datasets/raw/cherry-leaves/healthy/0008f3d3-2f85-4973-be9a-1b520b8b59fc___JR_HL 4092_flipTB.JPG
#   inflating: inputs/datasets/raw/cherry-leaves/healthy/002efba9-09b3-43de-93b7-5c2460185cde___JR_HL 9655.JPG
#   inflating: inputs/datasets/raw/cherry-leaves/healthy/0048afb8-b950-4c57-9e72-7e26282327ee___JR_HL 9765.JPG
#   inflating: inputs/datasets/raw/cherry-leaves/healthy/0048afb8-b950-4c57-9e72-7e26282327ee___JR_HL 9765_180deg.JPG
#   inflating: inputs/datasets/raw/cherry-leaves/healthy/0048afb8-b950-4c57-9e72-7e26282327ee___JR_HL 9765_flipTB.JPG
#   inflating: inputs/datasets/raw/cherry-leaves/healthy/005f183c-0a73-4738-91f7-c0a0e02cd9e3___JR_HL 9679.JPG
# ...

# %% [markdown]
# # Load and Inspect Kaggle data

# %% [markdown]
# Check contents of folder

# %%
import os

folder_path = "/workspace/cherryleaves/inputs/datasets/raw/cherry-leaves"
files = os.listdir(folder_path)
print("Files in cherry-leaves folder:", files)
# Out:
# Files in cherry-leaves folder: ['healthy', 'powdery_mildew']

# %% [markdown]
# Check the contents of the healthy leaves folder and the powery mildew leaves folder

# %%
import os

healthy_dir = "/workspace/cherryleaves/inputs/datasets/raw/cherry-leaves/healthy"
mildew_dir = "/workspace/cherryleaves/inputs/datasets/raw/cherry-leaves/powdery_mildew"

print("Healthy leaf images:", os.listdir(healthy_dir))
print("Powdery mildew leaf images:", os.listdir(mildew_dir))
# Out:
# Healthy leaf images: ['0008f3d3-2f85-4973-be9a-1b520b8b59fc___JR_HL 4092.JPG', '0008f3d3-2f85-4973-be9a-1b520b8b59fc___JR_HL 4092_180deg.JPG', '0008f3d3-2f85-4973-be9a-1b520b8b59fc___JR_HL 4092_flipTB.JPG', '002efba9-09b3-43de-93b7-5c2460185cde___JR_HL 9655.JPG', '0048afb8-b950-4c57-9e72-7e26282327ee___JR_HL 9765.JPG', '0048afb8-b950-4c57-9e72-7e26282327ee___JR_HL 9765_180deg.JPG', '0048afb8-b950-4c57-9e72-7e26282327ee___JR_HL 9765_flipTB.JPG', '005f183c-0a73-4738-91f7-c0a0e02cd9e3___JR_HL 9679.JPG', '0086a8c7-1440-423e-939d-d0567b1fc4e4___JR_HL 4277.JPG', '0086a8c7-1440-423e-939d-d0567b1fc4e4___JR_HL 4277_180deg.JPG', '0086a8c7-1440-423e-939d-d0567b1fc4e4___JR_HL 4277_flipTB.JPG', '00a8e886-d172-4261-85e2-780b3c50ad4d___JR_HL 4156.JPG', '011f07d1-8813-4a63-99c7-e274ab5cc261___JR_HL 4165.JPG', '011f07d1-8813-4a63-99c7-e274ab5cc261___JR_HL 4165_180deg.JPG', '011f07d1-8813-4a63-99c7-e274ab5cc261___JR_HL 4165_flipTB.JPG', '014161fb-3c15-414b-9af3-00cb51a11d7c___JR_HL 9842.JPG', '014161f
# ...

# %% [markdown]
# ---

# %% [markdown]
# # **SECTION 2: Data Cleaning**

# %% [markdown]
# Verify image files for inspection

# %% [markdown]
# Install Pillow library for image processing and Matplotlib library for image viewing

# %%
# !pip install pillow

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 95.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 51.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 86.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image

healthy_image = Image.open(healthy_image_path)

# Display the image in the notebook using matplotlib
plt.imshow(healthy_image)
plt.axis('off')  # Hide axes
plt.show()

# Repeat for mildew image
mildew_image = Image.open(mildew_image_path)
plt.imshow(mildew_image)
plt.axis('off')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # **SECTION 3: Push files to Repo**

# %% [markdown]
# * If you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
    # create here your folder
    # os.makedirs(name='')
except Exception as e:
    print(e)
